# %%
#Dependencies
import pandas as pd
import billboard as bb

# %%
#Import music.csv
music_file_path = "Resources/music.csv"
music_file = pd.read_csv(music_file_path)
music_file_db = pd.DataFrame(music_file)
music_file_db.head()
# Out:
#    artist.hotttnesss           artist.id       artist.name  \
# 0           0.401998  ARD7TVE1187B99BFB1            Casual
# 1           0.417500  ARMJAGH1187FB546F3      The Box Tops
# 2           0.343428  ARKRRTF1187B9984DA  Sonora Santanera
# 3           0.454231  AR7G5I41187FB4CE6C          Adam Ant
# 4           0.401724  ARXR32B1187FB57099               Gob
#
#           artist_mbtags  artist_mbtags_count  bars_confidence  bars_start  \
# 0                   NaN                  0.0            0.643     0.58521
# 1  classic pop and rock                  1.0            0.007     0.71054
# 2                   NaN                  0.0            0.980     0.73152
# 3                    uk                  1.0            0.017     1.30621
# 4                   NaN                  0.0            0.175     1.06368
#
#    beats_confidence  beats_start   duration  ...   start_of_fade_out  \
# 0             0.834      0.58521  218.93179  ...             218.932
# ...

# %%
bb.details
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-910c6be1e08c> in <module>
# ----> 1 bb.details
#
# AttributeError: module 'billboard' has no attribute 'details'

# %%
music_file_db = music_file_db.sort_values("year", axis = 0, ascending = False)
music_file_db.head()
# Out:
#       artist.hotttnesss           artist.id             artist.name  \
# 6637           0.363132  ARI28VJ1187FB4EAD7               Slackbaba
# 9800           0.517259  ARMD6JB1187FB3B0E7  Die Fantastischen Vier
# 4002           0.465489  ARRBTUP1242077FA75             Taking Dawn
# 1535           0.465500  ARQI60P1187FB464C9               The Ocean
# 3587           0.404117  ARVI9KK1187B9AACB4               Jan Wayne
#
#      artist_mbtags  artist_mbtags_count  bars_confidence  bars_start  \
# 6637           NaN                  0.0            0.069     1.05625
# 9800        german                  2.0            0.087     0.28284
# 4002           NaN                  0.0            0.014     0.66913
# 1535           NaN                  0.0            0.046     0.75178
# 3587           NaN                  0.0            0.476     0.52046
#
#       beats_confidence  beats_start   duration  ...   start_of_fade_out  \
# ...
