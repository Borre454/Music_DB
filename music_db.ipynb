# %%
import pandas as pd

# %%
music_file_path = "Resources/music.csv"
music_file = pd.read_csv(music_file_path)
music_file_db = pd.DataFrame(music_file)
music_file_db.head()
# Out:
#    artist.hotttnesss           artist.id       artist.name  \
# 0           0.401998  ARD7TVE1187B99BFB1            Casual
# 1           0.417500  ARMJAGH1187FB546F3      The Box Tops
# 2           0.343428  ARKRRTF1187B9984DA  Sonora Santanera
# 3           0.454231  AR7G5I41187FB4CE6C          Adam Ant
# 4           0.401724  ARXR32B1187FB57099               Gob
#
#           artist_mbtags  artist_mbtags_count  bars_confidence  bars_start  \
# 0                   NaN                  0.0            0.643     0.58521
# 1  classic pop and rock                  1.0            0.007     0.71054
# 2                   NaN                  0.0            0.980     0.73152
# 3                    uk                  1.0            0.017     1.30621
# 4                   NaN                  0.0            0.175     1.06368
#
#    beats_confidence  beats_start   duration  ...   start_of_fade_out  \
# 0             0.834      0.58521  218.93179  ...             218.932
# ...

# %%
spotify_df=pd.read_csv("Resources/featuresdf.csv")
spotify_df.head()
# Out:
#                       id                                name  \
# 0  7qiZfU4dY1lWllzX7mPBI                        Shape of You
# 1  5CtI0qwDJkDQGwXD1H1cL                   Despacito - Remix
# 2  4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 3  6RUKPb4LETWmmr3iAEQkt            Something Just Like This
# 4  3DXncPQOG4VBw3QHh3S81                         I'm the One
#
#             artists  danceability  energy   key  loudness  mode  speechiness  \
# 0        Ed Sheeran         0.825   0.652   1.0    -3.183   0.0       0.0802
# 1        Luis Fonsi         0.694   0.815   2.0    -4.328   1.0       0.1200
# 2        Luis Fonsi         0.660   0.786   2.0    -4.757   1.0       0.1700
# 3  The Chainsmokers         0.617   0.635  11.0    -6.769   0.0       0.0317
# 4         DJ Khaled         0.609   0.668   7.0    -4.284   1.0       0.0367
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
social_df=pd.read_csv("Resources/Artist_socialmedia.csv")
social_df.head()
# Out:
#               name                                 facebook  \
# 0            Adele       http://www.facebook.com/9770929278
# 1      Joey + Rory      http://www.facebook.com/15044507815
# 2  Draaco Aventura  http://www.facebook.com/856796091053581
# 3    Justin Bieber     http://www.facebook.com/309570926875
# 4  Peer van Mladen        http://www.facebook.com/264487966
#
#                                   twitter  \
# 0    http://www.twitter.com/officialadele
# 1      http://www.twitter.com/joeyandrory
# 2   http://www.twitter.com/DraacoAventura
# 3     http://www.twitter.com/justinbieber
# 4  http://www.twitter.com/Predrag_Jugovic
#
#                                          website       genre  \
# 0                                            NaN         Pop
# 1                                            NaN     Country
# 2         http://www.bandpage.com/draacoaventura  Pop Latino
# 3               http://www.justinbiebermusic.com         Pop
# ...

# %%
#clean up social media df for just facebook and twitter with artist name
new_social_df = social_df[["name","facebook","twitter","website"]].copy()
new_social_df=new_social_df.rename(columns={"name":"artists"})
new_social_df.head()
# Out:
#            artists                                 facebook  \
# 0            Adele       http://www.facebook.com/9770929278
# 1      Joey + Rory      http://www.facebook.com/15044507815
# 2  Draaco Aventura  http://www.facebook.com/856796091053581
# 3    Justin Bieber     http://www.facebook.com/309570926875
# 4  Peer van Mladen        http://www.facebook.com/264487966
#
#                                   twitter  \
# 0    http://www.twitter.com/officialadele
# 1      http://www.twitter.com/joeyandrory
# 2   http://www.twitter.com/DraacoAventura
# 3     http://www.twitter.com/justinbieber
# 4  http://www.twitter.com/Predrag_Jugovic
#
#                                          website
# 0                                            NaN
# 1                                            NaN
# 2         http://www.bandpage.com/draacoaventura
# 3               http://www.justinbiebermusic.com
# 4  http://pejaintergroup.eu/Peer_van_Mladen.html

# %%
new_spotify_df = spotify_df[['id', 'name', 'artists']].copy()
new_spotify_df=new_spotify_df.rename(columns={"id":"Spotify_id"})
new_spotify_df.head()
# Out:
#               Spotify_id                                name           artists
# 0  7qiZfU4dY1lWllzX7mPBI                        Shape of You        Ed Sheeran
# 1  5CtI0qwDJkDQGwXD1H1cL                   Despacito - Remix        Luis Fonsi
# 2  4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)        Luis Fonsi
# 3  6RUKPb4LETWmmr3iAEQkt            Something Just Like This  The Chainsmokers
# 4  3DXncPQOG4VBw3QHh3S81                         I'm the One         DJ Khaled

# %%
spotify_drop = new_spotify_df.drop_duplicates('artists')
spotify_drop.head()
# Out:
#               Spotify_id                      name           artists
# 0  7qiZfU4dY1lWllzX7mPBI              Shape of You        Ed Sheeran
# 1  5CtI0qwDJkDQGwXD1H1cL         Despacito - Remix        Luis Fonsi
# 3  6RUKPb4LETWmmr3iAEQkt  Something Just Like This  The Chainsmokers
# 4  3DXncPQOG4VBw3QHh3S81               I'm the One         DJ Khaled
# 5  7KXjTSCq5nL1LoYtL7XAw                   HUMBLE.    Kendrick Lamar

# %%
merged_df = pd.merge(spotify_drop, new_social_df, on="artists",how="left")
merged_df.head()
# Out:
#               Spotify_id                      name           artists  \
# 0  7qiZfU4dY1lWllzX7mPBI              Shape of You        Ed Sheeran
# 1  5CtI0qwDJkDQGwXD1H1cL         Despacito - Remix        Luis Fonsi
# 2  6RUKPb4LETWmmr3iAEQkt  Something Just Like This  The Chainsmokers
# 3  3DXncPQOG4VBw3QHh3S81               I'm the One         DJ Khaled
# 4  7KXjTSCq5nL1LoYtL7XAw                   HUMBLE.    Kendrick Lamar
#
#                                   facebook  \
# 0       http://www.facebook.com/9189674485
# 1                                      NaN
# 2  http://www.facebook.com/198933856805679
# 3  http://www.facebook.com/605083229565089
# 4     http://www.facebook.com/241273033091
#
#                                   twitter                         website
# 0        http://www.twitter.com/edsheeran       http://www.edsheeran.com/
# 1                                     NaN                             NaN
# ...
